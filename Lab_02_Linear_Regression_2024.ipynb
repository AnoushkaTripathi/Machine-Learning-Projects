# %% [markdown]
# <a href="https://colab.research.google.com/github/AnoushkaTripathi/Dimensionality-Reduction-with-LDA/blob/main/Lab_02_Linear_Regression_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**<font color='white'><b>Lab-02 Linear Regression With One Variable**
#
# > Experiment

# %% [markdown]
# In the first part of the exercise, we're tasked with implementing linear regression with one variable to predict profits for a food truck. Suppose you are the CEO of a restaurant franchise and are considering different cities for opening a new outlet. The chain already has trucks in various cities and you have data for profits and populations from the cities.
#
# **Let's start by importing some libraries and examining the data.**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-58bfccd0-fedd-42d2-a6fa-4792d9032f8b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-58bfccd0-fedd-42d2-a6fa-4792d9032f8b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv("/content/ex1data1 (1).csv", names=["Population", "Profit"])
data.head()
# Out:
#    Population   Profit
# 0      6.1101  17.5920
# 1      5.5277   9.1302
# 2      8.5186  13.6620
# 3      7.0032  11.8540
# 4      5.8598   6.8233

# %%
data.tail()
# Out:
#     Population   Profit
# 92      5.8707  7.20290
# 93      5.3054  1.98690
# 94      8.2934  0.14454
# 95     13.3940  9.05510
# 96      5.4369  0.61705

# %%
data.plot(x='Population', y = 'Profit', kind = 'scatter')
# Out:
# <Axes: xlabel='Population', ylabel='Profit'>

# %%
data.describe()
# Out:
#        Population     Profit
# count   97.000000  97.000000
# mean     8.159800   5.839135
# std      3.869884   5.510262
# min      5.026900  -2.680700
# 25%      5.707700   1.986900
# 50%      6.589400   4.562300
# 75%      8.578100   7.046700
# max     22.203000  24.147000

# %%
data.shape
# Out:
# (97, 2)

# %%
data.insert(0, "Ones", 1)
data
# Out:
#     Ones  Population    Profit
# 0      1      6.1101  17.59200
# 1      1      5.5277   9.13020
# 2      1      8.5186  13.66200
# 3      1      7.0032  11.85400
# 4      1      5.8598   6.82330
# ..   ...         ...       ...
# 92     1      5.8707   7.20290
# 93     1      5.3054   1.98690
# 94     1      8.2934   0.14454
# 95     1     13.3940   9.05510
# 96     1      5.4369   0.61705
#
# [97 rows x 3 columns]

# %%
data.shape
# Out:
# (97, 3)

# %%
cols = data.shape[1]
x = data.iloc[:, 0:cols-1]
y = data.iloc[:, cols-1:cols]

x.head()
# Out:
#    Ones  Population
# 0     1      6.1101
# 1     1      5.5277
# 2     1      8.5186
# 3     1      7.0032
# 4     1      5.8598

# %%
y.head()
# Out:
#     Profit
# 0  17.5920
# 1   9.1302
# 2  13.6620
# 3  11.8540
# 4   6.8233

# %%
X.shape,theta.shape,y.shape
# Out:
# ((97, 2), (1, 2), (97, 1))

# %%
def computeCost(X,y,theta):
    inner=np.power(((X*(np.transpose(theta)))-y),2)
    cost= np.sum(inner)/(2*(X.shape[0]))
    return cost

# %%
X=np.matrix(x)
Y=np.matrix(y)
theta=np.matrix(np.array([0,0]))

# %%
theta
# Out:
# matrix([[0, 0]])

# %%
computeCost(X,y,theta)
len(theta)
# Out:
# 1

# %%
def gradientDescent(X, y, theta, alpha, iters):
  temp = np.matrix(np.zeros(theta.shape))
  parameters =int(theta.ravel().shape[1])
  Cost=np.zeros(iters)
  for i in range(iters):
    error = (X*theta.T)-Y
    for j in range(parameters):
      term =np.multiply(error,X[:,j])
      temp[0,j] = theta[0,j]-((alpha/len(X))*np.sum(term))
    theta =temp
    Cost[i]=computeCost(X,y,theta)
  return theta,Cost

# %%
alpha=0.001
iters =2000

# %%
Theta, C = gradientDescent(X, y, theta, alpha, iters)
Theta,C
# Out:
# (matrix([[-1.12369018,  0.91454707]]),
#  array([27.94761975, 24.47289937, 21.54601437, ...,  5.17706722,
#          5.17681485,  5.17656256]))

# %%
computeCost(X, y, Theta)
# Out:
# Profit    5.176563
# dtype: float64

# %%
fig,ax=plt.subplots(figsize=(5,4))
ax.plot(np.arange(iters),C,'r')
ax.set_xlabel('Iterations')
ax.set_ylabel('Cost')
ax.set_title('Error vs. Training Epoch')
# Out:
# Text(0.5, 1.0, 'Error vs. Training Epoch')

# %%
x=np.linspace(data.Population.min(),data.Population.max(),100)
h=Theta[0,0]+(Theta[0,1]*x)
fig,ax=plt.subplots(figsize=(8,5))
ax.plot(x,h,'r',label='Prediction')
ax.scatter(data.Population,data.Profit,label='Training Data')
ax.legend(loc=2)
ax.set_xlabel('Population')
ax.set_ylabel('Profit')
ax.set_title('Predicted Profit vs. Population Size')
# Out:
# Text(0.5, 1.0, 'Predicted Profit vs. Population Size')

# %% [markdown]
# **Lab-01(b) Linear Regression with multiple Variables**
